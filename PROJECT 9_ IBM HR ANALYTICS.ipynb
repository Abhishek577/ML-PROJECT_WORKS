# %% [raw]
# Task:
# Here the task is to find the role of different variables which results in employee leaving the company or company replacing them which is also called as aberation.Aberation is a burden for the companies
#
# Education
# 1 'Below College'
# 2 'College'
# 3 'Bachelor'
# 4 'Master'
# 5 'Doctor'
#
# EnvironmentSatisfaction
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# JobInvolvement
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# JobSatisfaction
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# PerformanceRating
# 1 'Low'
# 2 'Good'
# 3 'Excellent'
# 4 'Outstanding'
#
# RelationshipSatisfaction
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# WorkLifeBalance
# 1 'Bad'
# 2 'Good'
# 3 'Better'
# 4 'Best'

# %%
#IMPORTING IMPORTANT LIBRARIES TO PERFORM NECESSARY EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset
ibm=pd.read_csv('IBMHR.csv')
ibm
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
type(ibm)
# Out:
# pandas.core.frame.DataFrame

# %%
ibm.head(4)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# ...

# %%
ibm.tail(4)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# ...

# %%
ibm.min()
# Out:
# Age                                                18
# Attrition                                          No
# BusinessTravel                             Non-Travel
# DailyRate                                         102
# Department                            Human Resources
# DistanceFromHome                                    1
# Education                                           1
# EducationField                        Human Resources
# EmployeeCount                                       1
# EmployeeNumber                                      1
# EnvironmentSatisfaction                             1
# Gender                                         Female
# HourlyRate                                         30
# JobInvolvement                                      1
# JobLevel                                            1
# JobRole                     Healthcare Representative
# JobSatisfaction                                     1
# ...

# %%
ibm.max()
# Out:
# Age                                           60
# Attrition                                    Yes
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1499
# Department                                 Sales
# DistanceFromHome                              29
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                              2068
# EnvironmentSatisfaction                        4
# Gender                                      Male
# HourlyRate                                   100
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              19999
# ...

# %%
ibm.mean()
# Out:
# Age                            36.923810
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1024.865306
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyIncome                6502.931293
# MonthlyRate                 14313.103401
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.209524
# PerformanceRating               3.153741
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# ...

# %%
ibm.median()
# Out:
# Age                            36.0
# DailyRate                     802.0
# DistanceFromHome                7.0
# Education                       3.0
# EmployeeCount                   1.0
# EmployeeNumber               1020.5
# EnvironmentSatisfaction         3.0
# HourlyRate                     66.0
# JobInvolvement                  3.0
# JobLevel                        2.0
# JobSatisfaction                 3.0
# MonthlyIncome                4919.0
# MonthlyRate                 14235.5
# NumCompaniesWorked              2.0
# PercentSalaryHike              14.0
# PerformanceRating               3.0
# RelationshipSatisfaction        3.0
# StandardHours                  80.0
# StockOptionLevel                1.0
# TotalWorkingYears              10.0
# TrainingTimesLastYear           3.0
# WorkLifeBalance                 3.0
# YearsAtCompany                  5.0
# YearsInCurrentRole              3.0
# YearsSinceLastPromotion         1.0
# YearsWithCurrManager            3.0
# ...

# %%
ibm.std()
# Out:
# Age                            9.135373
# DailyRate                    403.509100
# DistanceFromHome               8.106864
# Education                      1.024165
# EmployeeCount                  0.000000
# EmployeeNumber               602.024335
# EnvironmentSatisfaction        1.093082
# HourlyRate                    20.329428
# JobInvolvement                 0.711561
# JobLevel                       1.106940
# JobSatisfaction                1.102846
# MonthlyIncome               4707.956783
# MonthlyRate                 7117.786044
# NumCompaniesWorked             2.498009
# PercentSalaryHike              3.659938
# PerformanceRating              0.360824
# RelationshipSatisfaction       1.081209
# StandardHours                  0.000000
# StockOptionLevel               0.852077
# TotalWorkingYears              7.780782
# TrainingTimesLastYear          1.289271
# WorkLifeBalance                0.706476
# YearsAtCompany                 6.126525
# ...

# %%
dups=ibm.duplicated(keep='first').sum()
print('There are',dups,'duplicated values found')
# Out:
# There are 0 duplicated values found

# %%
ibm.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# No trace of null values

# %%
ibm.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
ibm.groupby(ibm['Attrition']).mean()
# Out:
#                  Age   DailyRate  DistanceFromHome  Education  EmployeeCount  \
# Attrition
# No         37.561233  812.504461          8.915653   2.927007            1.0
# Yes        33.607595  750.362869         10.632911   2.839662            1.0
#
#            EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# Attrition
# No            1027.656123                 2.771290   65.952149
# Yes           1010.345992                 2.464135   65.573840
#
#            JobInvolvement  JobLevel  ...  RelationshipSatisfaction  \
# Attrition                            ...
# No               2.770479  2.145985  ...                  2.733982
# Yes              2.518987  1.637131  ...                  2.599156
#
#            StandardHours  StockOptionLevel  TotalWorkingYears  \
# Attrition
# No                  80.0          0.845093          11.862936
# Yes                 80.0          0.527426           8.244726
#
# ...

# %%
#performing a cross tab operation of all objecttype attribute with attrition
c=ibm.columns.values
for i in (2,4,6,7,8,10,11,13,14,15,16,17,21,23,25,30):
    ctab=pd.crosstab(ibm[c[i]],ibm['Attrition'])
    print('\nthe number of attrition with respect to ',c[i],'\n','----'*20,'\n',ctab)
# Out:
# the number of attrition with respect to  BusinessTravel
#  --------------------------------------------------------------------------------
#  Attrition           No  Yes
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156
#
# the number of attrition with respect to  Department
#  --------------------------------------------------------------------------------
#  Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92
#
# the number of attrition with respect to  Education
#  --------------------------------------------------------------------------------
#  Attrition   No  Yes
# Education
# 1          139   31
# 2          238   44
# 3          473   99
# 4          340   58
# 5           43    5
#
# the number of attrition with respect to  EducationField
# ...

# %%
#value_count of object types
for i in (1,2,4,6,7,10,11,13,14,15,16,17,22,25,30):
    vc=ibm[c[i]].value_counts()
    print('\nthe number of unique values of',c[i],'\n','----'*20,'\n',vc)
# Out:
# the number of unique values of Attrition
#  --------------------------------------------------------------------------------
#  No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
# the number of unique values of BusinessTravel
#  --------------------------------------------------------------------------------
#  Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
# the number of unique values of Department
#  --------------------------------------------------------------------------------
#  Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
# the number of unique values of Education
#  --------------------------------------------------------------------------------
#  3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64
#
# the number of unique values of EducationField
# ...

# %%
ibm.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
o=['object']
ibm.describe(include=o)
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# Implementing Graphical Method For More Exploration Of The Data

# %%
n=ibm['Attrition'].value_counts()
n
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(7,9))
sns.set_context('talk',font_scale=1)
sns.set(style='darkgrid')

n=ibm['Attrition'].value_counts().tolist()
tm=('NO','YES')
print("n=", n,'\n------------------\ntm=',tm)
clr=['aqua','mediumspringgreen']
e=(0.2, 0)
plt.pie(n, explode=e, labels=tm, colors=clr,autopct='%1.1f%%' ,shadow=True)
plt.title('PERCENTAGE OF ATTRITION IN COMPANIES')
plt.show()
# Out:
# n= [1233, 237]
# ------------------
# tm= ('NO', 'YES')

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='BusinessTravel',hue='Attrition',data=ibm,orient='v',palette='hot',saturation=35)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYEES TAKING BUSINESS TRIPS')
plt.show()

# %% [markdown]
#                        THE ATTARATION OF EMPLOYEES WHO TRAVELS RARELY IS HIGHER AS COMPARED TO OTHERS

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='Department',hue='Attrition',data=ibm,orient='v',palette='cubehelix',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYEES FROM DIFFERENT DEPT.')
plt.show()

# %% [markdown]
#                                     THE R&D DEPARTMENT HAS SEEN THE MAXIMUM ATTRITIONS

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='Education',hue='Attrition',data=ibm,orient='v',palette='gist_ncar_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYEES OF VARIOUS QUALIFICATION')
plt.show()

# %% [markdown]
#                     COMPANY'S HAVE SUFFER FROM ATTRITIONS OF EMPLOYEES WITH BACHELOR DEGREE
#                       (1='Below College'/2='College'/3='Bachelor'/4='Master'/5='Doctor)

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='EducationField',hue='Attrition',data=ibm,orient='v',palette='ocean',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYEES OF VARIOUS EDUCATIONAL FIELDS')
plt.show()

# %% [markdown]
#            ATTARATION OF EMPLOYEES WITH LIFE SCIENCE BACKGROUND IS HIGH AS COMPARED TO EMPLOYEES OF OTHER EDUCATIONAL FIELD

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='EnvironmentSatisfaction',hue='Attrition',data=ibm,orient='v',palette='YlOrRd_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING ON ENVIRONMENT SATISFACTION')
plt.show()

# %% [markdown]
#                      LOW ENVIRONMENTAL SATISFACTION LEADS TO HIGH RATE OF ATTARITIONS
#                     (Environment Satisfaction:1='Low'/2='Medium'/3='High'/4='Very High)

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='Gender',hue='Attrition',data=ibm,orient='v',palette='terrain_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING THEIR GENDER')
plt.show()

# %% [markdown]
#                                     ATTARITION IN CASE OF MALE EMPLOYEES IS HIGH

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='JobLevel',hue='Attrition',data=ibm,orient='v',palette='gist_earth_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING THEIR RANK')
plt.show()

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='JobInvolvement',hue='Attrition',data=ibm,orient='v',palette='summer_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING THEIR INVOLMENT IN WORK')
plt.show()

# %% [markdown]
#                                 A HIGH JOB INVOLVEMENT LEADS TO HIGH ATTARITION
#                             (JobInvolvement:1='Low'/2='Medium'/3='High'/4='Very High')

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
M1=sns.countplot(x='JobRole',hue='Attrition',data=ibm,orient='v',palette='jet_r',saturation=25)
M1.set_xticklabels(M1.get_xticklabels(),rotation=60)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING THEIR ROLE')
plt.show()

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='JobSatisfaction',hue='Attrition',data=ibm,orient='v',palette='twilight_shifted_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING ON THEIR JOB SATISFACTION')
plt.show()

# %% [markdown]
#                     LOWER THE JOB SATISFACTION HIGHER THE ATTARITION
#                 (JobSatisfaction:1='Low'/2='Medium'/3='High'/4='Very High')

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='MaritalStatus',hue='Attrition',data=ibm,orient='v',palette='prism',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING ON THEIR JOB SATISFACTION')
plt.show()

# %% [markdown]
#                     THE COUNT OF ATTRITION OF SINGLE EMPLOYEE ARE HIGH AS COMPARED TO OTHER STATUS

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='OverTime',hue='Attrition',data=ibm,orient='v',palette='inferno',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES BASING ON DOING OVER TIME')
plt.show()

# %% [markdown]
#         THE ATTARITION OF EMPLOYEE DOING OVERTIME ARE HIGH AS COMPARED TO EMPLOYEE NOT DOING OVERTIME

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='WorkLifeBalance',hue='Attrition',data=ibm,orient='v',palette='BuGn_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES AND THEIR WORK LIFE')
plt.show()

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.countplot(x='RelationshipSatisfaction',hue='Attrition',data=ibm,orient='v',palette='bone_r',saturation=25)
plt.title('PLOT TO SHOW THE COUNT OF ATTARITION OF EMPLOYES AND RELATIONSHIP SATISFACTION')
plt.show()

# %% [markdown]
#                     A HIGH RELATIONSHIP SATISFACTION IS SHOWING A HIGH ATTARITION
#                 (RelationshipSatisfaction:1='Low'/2='Medium'/3='High'/4='Very High')

# %%
#BARPLOTS

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.barplot(x='Education',y='MonthlyIncome',hue='Attrition',data=ibm,ci=85,orient='v',palette='tab20_r',saturation=20,errcolor='navy',errwidth=3)
plt.show()

# %% [markdown]
#         EMPLOYEES WITH A DR DEGREE GET HIGH MONTHLY SALARY BUT AT LOW SALARY THE ATTRITION IS ALSO HIGH IN THIS CASE

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.barplot(x='YearsAtCompany',y='MonthlyIncome',data=ibm,ci=85,orient='v',palette='tab20_r',saturation=20,errcolor='navy',errwidth=3)
plt.show()

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.barplot(x='EducationField',y='Education',hue='Gender',data=ibm,ci=85,orient='v',palette='hsv',saturation=20,errcolor='red',errwidth=3)
plt.show()

# %% [markdown]
#                 OTHER FIELDS HAVE HIGHLY QUALIFIED MALE EMPLOYEES AS COMPARED TO OTHERS

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.barplot(x='EducationField',y='MonthlyIncome',hue='Gender',data=ibm,ci=85,orient='v',palette='hsv',saturation=20,errcolor='red',errwidth=3)
plt.show()

# %% [markdown]
#                                     The monthly income of Females of HR Field is high

# %%
plt.figure(figsize=(12,3),dpi=110)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.lineplot(x='Attrition', y='Age', hue='Gender',data=ibm, palette='Oranges',dashes=True, markers=None,estimator='mean', ci=65,sort=True,err_style='bars')
plt.title('PLOT TO SEE ATTRITION AT WRT AGE')
plt.show()

# %% [markdown]
#                 HIGH RATE OF ATTRITION IS SEEN IN CASE OF YOUNG EMPLOYEES AS COMPARED TO OLDER EMPLOYEE

# %%
plt.figure(figsize=(12,3),dpi=120)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.lineplot(x='Education',y='HourlyRate', hue='Attrition',data=ibm, palette='copper_r',dashes=True, markers=None,estimator='mean', ci=65,sort=True,err_style='bars')
plt.title('PLOT TO SEE ATTRITION AT WRT HOURLY RATE')
plt.show()

# %% [markdown]
#                                 THE HOURLY RATE IS HIGH FOR HIGHLY QUALIFIED EMPLOYEES

# %%
plt.figure(figsize=(12,3),dpi=120)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.lineplot(x='YearsAtCompany',y='PercentSalaryHike', hue='Attrition',data=ibm, palette='copper_r',dashes=True, markers=None,estimator='mean', ci=65,sort=True,err_style='bars')
plt.show()

# %%
plt.figure(figsize=(12,3),dpi=120)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.lineplot(x='EducationField',y='HourlyRate',hue='Attrition',data=ibm, palette='inferno',dashes=True, markers=None,estimator='mean', ci=65,sort=True,err_style='bars')
plt.show()

# %%
plt.figure(figsize=(12,3),dpi=120)
sns.set_context('talk',font_scale=0.9)
sns.set(style='darkgrid')
sns.lineplot(x='EducationField',y='YearsSinceLastPromotion',hue='Gender',data=ibm, palette='inferno',dashes=True, markers=None,estimator='mean', ci=65,sort=True,err_style='bars')
plt.show()

# %% [markdown]
#                     FEMALE EMPLOYEES GET PROMOTION EARLIER AS COMPARED TO MALE EMPLOYEES

# %%
#USING LABELENCODER TO CONVERT THE OBJECT TYPE IN TERMS OF NUMERICAL VALUES
lbl=LabelEncoder()
for i in ('Attrition','BusinessTravel','Department','EducationField','Gender',
          'JobRole','MaritalStatus','Over18','OverTime'):  
    ibm[i]=lbl.fit_transform(ibm[i])

# %%
plt.figure(figsize=(12,3),dpi=120)
ibm.hist(figsize=(20,20),grid=True,)
plt.show()

# %% [markdown]
# Dropping columns EmployeeCount as it is same throughout the dataset,StandardHour as it is the same 80 for all & Employeenumber as it is like a index

# %%
ibm.drop(['EmployeeCount','EmployeeNumber','StandardHours','Over18'],axis=1,inplace=True)

# %%
cl=ibm.columns.values
cl
# Out:
# array(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'], dtype=object)

# %%
#boxplot to visualize outliers 
plt.figure(figsize=(22,40),dpi=140)
sns.set_context('talk',font_scale=1)
sns.set(style='darkgrid')
for i in range (0,31):
    plt.subplot(7,11,i+1)
    sns.boxplot(ibm[cl[i]],orient='v',color='teal',saturation=15,width=2,linewidth=3)
plt.tight_layout()

# %%
#zscore
z=np.abs(zscore(ibm))
z
# Out:
# array([[0.4463504 , 2.28090588, 0.59004834, ..., 0.0632959 , 0.67914568,
#         0.24583399],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.76499762, 0.36871529,
#         0.80654148],
#        [0.008343  , 2.28090588, 0.59004834, ..., 1.16768726, 0.67914568,
#         1.15593471],
#        ...,
#        [1.08667552, 0.4384223 , 0.59004834, ..., 0.61549158, 0.67914568,
#         0.31487349],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.48889978, 0.67914568,
#         1.08689522],
#        [0.32016256, 0.4384223 , 0.59004834, ..., 0.33939374, 0.36871529,
#         0.59522723]])

# %%
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([30, 29, 27, 29, 28, 29, 24, 24, 27, 29, 28, 29, 30, 24, 27, 29, 30,
#        29, 24, 30, 27, 28, 29, 28, 30, 27, 29, 24, 27, 28, 29, 29, 30, 24,
# ...

# %%
print(z[28][30],'\n',z[1430][28])
# Out:
# 3.6100788863016295
#  3.249878181909428

# %%
hr=ibm[(z<3).all(axis=1)]

# %%
print('The shape before outlier removal:\t',ibm.shape,'\nThe shape after outlier removal:\t',hr.shape,
      '\nSo a total of',len(ibm)-len(hr),'rows has been removed')
# Out:
# The shape before outlier removal:	 (1470, 31)
# The shape after outlier removal:	 (1387, 31)
# So a total of 83 rows has been removed

# %%
#distplot
plt.figure(figsize=(25,50),dpi=120)
sns.set_context('paper',font_scale=1.3)
sns.set(style='darkgrid')
for i in range (0,31):
    plt.subplot(9,4,i+1)
    sns.distplot(hr[cl[i]],color='indigo',bins=60, hist=True, kde=True, rug=True)
plt.tight_layout()

# %%
hr.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# ...

# %%
#skew of 0.55 is allowable so any attribute having skew value more than 0.55 will be treated as skewed data and must be removed.
for i in hr.columns:
    if hr.skew().loc[i]>0.55:
        hr[i]=np.log1p(hr[i])

# %%
#pairplt and cor
hr_corr=hr.corr()
hr_corr
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159366        0.022340   0.021946
# Attrition                -0.159366   1.000000       -0.001041  -0.057220
# BusinessTravel            0.022340  -0.001041        1.000000  -0.004606
# DailyRate                 0.021946  -0.057220       -0.004606   1.000000
# Department               -0.038242   0.063637       -0.003521  -0.005398
# DistanceFromHome         -0.029146   0.080806       -0.014534  -0.003876
# Education                 0.198502  -0.032703       -0.010560  -0.018442
# EducationField           -0.032676   0.023585        0.022576   0.040645
# EnvironmentSatisfaction   0.014098  -0.112393        0.001183   0.033123
# Gender                   -0.039430   0.036252       -0.025364  -0.005242
# HourlyRate                0.025465  -0.001532        0.025424   0.014279
# JobInvolvement            0.036424  -0.133957        0.028261   0.048004
# ...

# %% [raw]
# HERE IN THIS DATASET THE ATTRITION IS THE TARGET COLUMN WHICH IS GIVING A BINARY OUTPUT
# SO IT'S A CLASSIFICATION BASED PROBLEM AND WE CAN USE THE FOLLOWING ALGORITHMS
# LogisticRegression
# SupportVectorClassifier
# KNeighborsClassifier
# DecisionTreeClassifier
# GaussianNB
# RandomForestClassifier
# GradientBoostingClassifier
#
# For best parameter for each model for better performance we'll use RandomizedSearchCV
# For Boosting a less performing algorithm we can use AdaBoostClassifier
# Atlast to view the model performance AUC_ROC score will be used

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score as cvs ,RandomizedSearchCV as rsv
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import roc_curve,roc_auc_score,auc

from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier

import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
hr.head(5)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41   0.693147               2       1102           2          0.693147
# 1   49   0.000000               1        279           1          2.197225
# 2   37   0.693147               2       1373           1          1.098612
# 3   33   0.000000               1       1392           1          1.386294
# 4   27   0.000000               2        591           1          1.098612
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
ibm.head(5)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# -As we are to apply algorithms of classification and logistic regression taking Attrition as our target but we can see that it is giving a continious value instead of a discrete value after z score treatment
#
# -By comparing the old and new dataset we can see that all the cases of Attrition with 0 values remains same in both the dataset i.e the old dataset(ibm) & the new dataset(hr)
# but all cases with 1 of old dataset,ibm becomes 0.693147 in the new dataset 'hr' as a results of outliers removal and zscore process.
#
# so we will bring those values to their original form by using round function and astype method.

# %%
hr['Attrition']=hr['Attrition'].round()

# %%
hr['Attrition']=hr['Attrition'].astype('int32')

# %%
hr.head(3)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2          0.693147
# 1   49          0               1        279           1          2.197225
# 2   37          1               2       1373           1          1.098612
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0           1.386294                         1          0.000000
# 1           1.609438                         4          0.693147
# 2           1.386294                         2          0.000000
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
ibm.head(3)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %% [markdown]
# we can now check that the 'attrition' column gets back to its Earlier form

# %%
#splitting the dataset into X and Y for training and testing
x=hr.drop(['Attrition'],axis=1)
y=hr['Attrition']
print('x:',"--"*30,"\n", x,'\nshape of x:', x.shape)
print('\ny:',"--"*30,"\n", y,'\nshape of y:', y.shape)
# Out:
# x: ------------------------------------------------------------
#        Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2          0.693147          2
# 1      49               1        279           1          2.197225          1
# 2      37               2       1373           1          1.098612          2
# 3      33               1       1392           1          1.386294          4
# 4      27               2        591           1          1.098612          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1          3.178054          2
# 1466   39               2        613           1          1.945910          1
# 1467   27               2        155           1          1.609438          3
# 1468   49               1       1023           2          1.098612          3
# ...

# %%
#converting y into  np.array format form pandas.core.series.Series form and reshaping it in the form of 1 columns and many rows
y=np.array(y)
y=y.reshape(-1,1)
y
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
#Using StandardScaler Feature to standardise the values of x
ss=StandardScaler()
x=ss.fit_transform(x)
print(x)
# Out:
# [[ 0.5366811   0.59312579  0.73432467 ...  0.37256681 -0.96408623
#    0.62864663]
#  [ 1.44211114 -0.90535412 -1.30776866 ...  0.98090913 -0.02809563
#    0.99384363]
#  [ 0.08396607  0.59312579  1.40675151 ... -1.7105856  -0.96408623
#   -1.64589615]
#  ...
#  [-1.04782149  0.59312579 -1.61544736 ... -0.28861286 -0.96408623
#    0.11393037]
#  [ 1.44211114 -0.90535412  0.53830356 ...  0.80807473 -0.96408623
#    1.14336289]
#  [-0.2555702   0.59312579 -0.44180199 ...  0.08374422 -0.02809563
#   -0.25126663]]

# %%
print('shape of x=', x.shape)
print('shape of y=', y.shape)
# Out:
# shape of x= (1387, 30)
# shape of y= (1387, 1)

# %%
#creating a function to achive the highest perfoming random score for all model to be used
def acusr(model,x,y):
    max_ac_score=0
    for rst in range(25,180):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=rst)
        model.fit(x_train,y_train)
        pred=model.predict(x_test)
        ascr=accuracy_score(pred,y_test)
        f1=f1_score(pred,y_test)
        clr=classification_report(y_test,pred)
        conf=confusion_matrix(y_test,pred)
        auc_scores=roc_auc_score(y_test,pred)
        if ascr>max_ac_score:
            max_ac_score=ascr
            final_rst=rst
    print("In this",model,'\n\nThe best suited random_score is: ', final_rst, '\n\nAccuracy score:', max_ac_score)
    print('\nF1 SCORE:', f1)
    print('\nCONFUSION MATRIX:\n',conf)
    print('\nAUC_ROC Score:\n',auc_scores)
    return final_rst

# %% [markdown]
# LOGISTIC REGRESSION

# %%
logi=LogisticRegression()
m1=acusr(logi,x,y)
# Out:
# In this LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# The best suited random_score is:  106
#
# Accuracy score: 0.9032921810699589
#
# F1 SCORE: 0.5517241379310345
#
# CONFUSION MATRIX:
#  [[381  20]
#  [ 45  40]]
#
# AUC_ROC Score:
#  0.7103564617867097

# %%
#using cross_val_score to check for over/under fitting of logistic regressor model
logi_accuracy=cvs(logi,x,y,scoring='accuracy',cv=30)
logi_roc_auc=cvs(logi,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT LOGISTIC MODEL IS=', logi_accuracy.mean())
print('THE AUC_ROC SCORE AT LOGISTIC MODEL IS=', logi_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT LOGISTIC MODEL IS= 0.8776064686332957
# THE AUC_ROC SCORE AT LOGISTIC MODEL IS= 0.8338032581453633

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
#using RandomizedSearchCV to get best parameters for optimum performance of DTC model

dtc=DecisionTreeClassifier()
dtc_para={'criterion':['gini','entropy'],'splitter':['best','random'],'max_depth': range(4,10),'min_samples_split':range(2,8)}
dtc_rs=rsv(dtc,dtc_para,cv=30)
dtc_rs.fit(x,y)
print(dtc_rs,'\n')
print(dtc_rs.best_score_,'\n')
print(dtc_rs.best_params_)
# Out:
# RandomizedSearchCV(cv=30, error_score='raise-deprecating',
#                    estimator=DecisionTreeClassifier(class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     presort=False,
#                                                     random_state=None,
# ...

# %%
dtc=DecisionTreeClassifier(splitter='random',min_samples_split=4,max_depth=4,criterion='gini')
m2=acusr(dtc,x,y)
# Out:
# In this DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='random')
#
# The best suited random_score is:  117
#
# Accuracy score: 0.8641975308641975
#
# F1 SCORE: 0.23214285714285715
#
# CONFUSION MATRIX:
#  [[387  14]
#  [ 72  13]]
#
# AUC_ROC Score:
#  0.5590142291330497

# %%
#using cross_val_score to check for over/under fitting of DTC model
dtc_accuracy=cvs(dtc,x,y,scoring='accuracy',cv=30)
dtc_roc_auc=cvs(dtc,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT DTC MODEL IS=', dtc_accuracy.mean())
print('THE AUC_ROC SCORE AT DTC MODEL IS=',  dtc_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT DTC MODEL IS= 0.8430616370301848
# THE AUC_ROC SCORE AT DTC MODEL IS= 0.7657637683953473

# %% [markdown]
# SUPPORT VECTOR CLASSIFIER

# %%
svc=SVC()
svc_para={'kernel':['rbf','poly','linear'],'gamma':[0.01,0.1],'degree':[3,5,7,9],'C':[3,5,6]}
svc_rsv=rsv(svc,svc_para,cv=30)
svc_rsv.fit(x,y)
print(svc_rsv)
print('\nbest score=', svc_rsv.best_score_)
print("\nbest parameters for SVC=\n",svc_rsv.best_params_)
# Out:
# RandomizedSearchCV(cv=30, error_score='raise-deprecating',
#                    estimator=SVC(C=1.0, cache_size=200, class_weight=None,
#                                  coef0=0.0, decision_function_shape='ovr',
#                                  degree=3, gamma='auto_deprecated',
#                                  kernel='rbf', max_iter=-1, probability=False,
#                                  random_state=None, shrinking=True, tol=0.001,
#                                  verbose=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'C': [3, 5, 6], 'degree': [3, 5, 7, 9],
#                                         'gamma': [0.01, 0.1],
#                                         'kernel': ['rbf', 'poly', 'linear']},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)
#
# best score= 0.8803172314347513
#
# best parameters for SVC=
# ...

# %%
svc=SVC(kernel='rbf',gamma=0.01,degree=3,C=5)
m3=acusr(svc,x,y)
# Out:
# In this SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# The best suited random_score is:  126
#
# Accuracy score: 0.8991769547325102
#
# F1 SCORE: 0.5185185185185185
#
# CONFUSION MATRIX:
#  [[386  15]
#  [ 50  35]]
#
# AUC_ROC Score:
#  0.6871791110459146

# %%
#using cross_val_score to check for over/under fitting of SVC model
svc_accuracy=cvs(svc,x,y,scoring='accuracy',cv=30)
svc_roc_auc=cvs(svc,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT SVC MODEL IS=', svc_accuracy.mean())
print('THE AUC_ROC SCORE AT SVC MODEL IS=',  svc_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT SVC MODEL IS= 0.8805063898310892
# THE AUC_ROC SCORE AT SVC MODEL IS= 0.8357777456461667

# %% [markdown]
# K NEIGHBORS CLASSIFIER

# %%
#using KNeighborsClassifier algo with RandomizedSearchCV to get best parameters for optimum performance
knc=KNeighborsClassifier()
knc_para={'n_neighbors':range(20,65),'algorithm':['ball_tree','kd_tree','brute'],'leaf_size':[10,30,35]}
knc_rsv=rsv(knc,knc_para,cv=30)
knc_rsv.fit(x,y)
print(knc_rsv)
print('\nbest score=',knc_rsv.best_score_)
print('\nbest parameters for KNC=\n',knc_rsv.best_params_)
# Out:
# RandomizedSearchCV(cv=30, error_score='raise-deprecating',
#                    estimator=KNeighborsClassifier(algorithm='auto',
#                                                   leaf_size=30,
#                                                   metric='minkowski',
#                                                   metric_params=None,
#                                                   n_jobs=None, n_neighbors=5,
#                                                   p=2, weights='uniform'),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'algorithm': ['ball_tree', 'kd_tree',
#                                                       'brute'],
#                                         'leaf_size': [10, 30, 35],
#                                         'n_neighbors': range(20, 65)},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)
#
# ...

# %%
knc=KNeighborsClassifier(n_neighbors=23,algorithm='brute',leaf_size=30)
m4=acusr(knc,x,y)
# Out:
# In this KNeighborsClassifier(algorithm='brute', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=23, p=2,
#                      weights='uniform')
#
# The best suited random_score is:  106
#
# Accuracy score: 0.8806584362139918
#
# F1 SCORE: 0.06818181818181818
#
# CONFUSION MATRIX:
#  [[401   0]
#  [ 82   3]]
#
# AUC_ROC Score:
#  0.5176470588235295

# %%
#using cross_val_score to check for over/under fitting of KNC model
knc_accuracy=cvs(knc,x,y,scoring='accuracy',cv=30)
knc_roc_auc=cvs(knc,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT KNC MODEL IS=', knc_accuracy.mean())
print('THE AUC_ROC SCORE AT KNC MODEL IS=',  knc_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT KNC MODEL IS= 0.8422564840511186
# THE AUC_ROC SCORE AT KNC MODEL IS= 0.760315452091768

# %% [markdown]
# GAUSSIAN NB

# %%
gnb=GaussianNB()
m5=acusr(gnb,x,y)
# Out:
# In this GaussianNB(priors=None, var_smoothing=1e-09)
#
# The best suited random_score is:  106
#
# Accuracy score: 0.8641975308641975
#
# F1 SCORE: 0.5291005291005291
#
# CONFUSION MATRIX:
#  [[347  54]
#  [ 35  50]]
#
# AUC_ROC Score:
#  0.7267859762358809

# %%
#using cross_val_score to check for over/under fitting of KNC model
gnb_accuracy=cvs(gnb,x,y,scoring='accuracy',cv=30)
gnb_roc_auc=cvs(gnb,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT GNB MODEL IS=', gnb_accuracy.mean())
print('THE AUC_ROC SCORE AT GNB MODEL IS=',  gnb_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT GNB MODEL IS= 0.817767499229109
# THE AUC_ROC SCORE AT GNB MODEL IS= 0.7751634695713643

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
rfc=RandomForestClassifier()
rfc_para={"n_estimators":[200,400],'max_depth':[6,9],'criterion':('gini','entropy')}
rfc_rsv=rsv(rfc,rfc_para,cv=30)
rfc_rsv.fit(x,y)
print(rfc_rsv)
print('\nbest score=',rfc_rsv.best_score_)
print('\nbest parameters for RFC=\n',rfc_rsv.best_params_)
# Out:
# RandomizedSearchCV(cv=30, error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators='warn',
# ...

# %%
rfc=RandomForestClassifier(n_estimators=400,max_depth=9,criterion='entropy')
m6=acusr(rfc,x,y)
# Out:
# In this RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=9, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=400,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
# The best suited random_score is:  106
#
# Accuracy score: 0.8909465020576132
#
# F1 SCORE: 0.2448979591836735
#
# CONFUSION MATRIX:
#  [[400   1]
#  [ 73  12]]
#
# AUC_ROC Score:
#  0.5693413525011002

# %%
rfc_accuracy=cvs(rfc,x,y,scoring='accuracy',cv=30)
rfc_roc_auc=cvs(rfc,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT RFC MODEL IS=', rfc_accuracy.mean())
print('THE AUC_ROC SCORE AT RFC MODEL IS=',  rfc_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT RFC MODEL IS= 0.8558423270634188
# THE AUC_ROC SCORE AT RFC MODEL IS= 0.8141346957136432

# %% [markdown]
# GRADIENT BOOSTING REGRESSOR

# %%
gbc=GradientBoostingClassifier()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=85)
para= {"learning_rate": [0.0001,0.025,0.01],"max_depth":range(5,9),"n_estimators":[250,450]}
gbc_rs= rsv(gbc,para,cv=30)
gbc_rs.fit(x_train,y_train)
print(gbc_rs)
print("\nbest parameters:",gbc_rs.best_params_)
print("\n best score:",gbc_rs.best_score_)
# Out:
# RandomizedSearchCV(cv=30, error_score='raise-deprecating',
#                    estimator=GradientBoostingClassifier(criterion='friedman_mse',
#                                                         init=None,
#                                                         learning_rate=0.1,
#                                                         loss='deviance',
#                                                         max_depth=3,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
# ...

# %%
gbc=GradientBoostingClassifier(learning_rate=0.025,max_depth=5,n_estimators=450)
m7=acusr(gbc,x,y)
# Out:
# In this GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.025, loss='deviance', max_depth=5,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=450,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
#
# The best suited random_score is:  106
#
# Accuracy score: 0.897119341563786
#
# F1 SCORE: 0.3875968992248063
#
# CONFUSION MATRIX:
#  [[382  19]
#  [ 60  25]]
#
# AUC_ROC Score:
#  0.6233680504620801

# %%
gbc_accuracy=cvs(gbc,x,y,scoring='accuracy',cv=30)
gbc_roc_auc=cvs(gbc,x,y,scoring='roc_auc',cv=30)
print('THE ACCURACY SCORE AT GBC MODEL IS=', gbc_accuracy.mean())
print('THE AUC_ROC SCORE AT GBC MODEL IS=',  gbc_roc_auc.mean())
# Out:
# THE ACCURACY SCORE AT GBC MODEL IS= 0.8496652619316819
# THE AUC_ROC SCORE AT GBC MODEL IS= 0.8049591125249018

# %% [raw]
# WE GOT ALL THE RANDOM STATE,ACCURACY_SCORE,AUC_ROC SCORE OF ALL ALGORITHMS WITH AND WITHOUT CROSSVALIDATION
# NOW PUTTING THEM IN ONE DATAFRAME FOR TABULAR FORM PROPER VISUALIZATION

# %%
results=[['LOGI REG',106,0.903292,0.710356,0.877606,0.833803],
      ['DTC',117,0.864197,0.559014,0.843061,0.765763],
      ['SVC',126,0.899176,0.687179,0.880506,0.835777],
      ['KNC',106,0.880658,0.517647,0.842256,0.760315],
      ['GNB',106,0.864197,0.726785,0.817767,0.775163],
      ['RFC',186,0.890946,0.569341,0.855842,0.814134],
      ['GBC',106,0.897119,0.623368,0.849665,0.804959]]
performance=pd.DataFrame(results,columns=['MODEL_NAME','RANDOM_ST','ACCURACY W\O CV',
                                'AUC SCORE W/O CV ','ACCURACY W CV','AUC SCORE W CV'])
performance
# Out:
#   MODEL_NAME  RANDOM_ST  ACCURACY W\O CV  AUC SCORE W/O CV   ACCURACY W CV  \
# 0   LOGI REG        106         0.903292           0.710356       0.877606
# 1        DTC        117         0.864197           0.559014       0.843061
# 2        SVC        126         0.899176           0.687179       0.880506
# 3        KNC        106         0.880658           0.517647       0.842256
# 4        GNB        106         0.864197           0.726785       0.817767
# 5        RFC        186         0.890946           0.569341       0.855842
# 6        GBC        106         0.897119           0.623368       0.849665
#
#    AUC SCORE W CV
# 0        0.833803
# 1        0.765763
# 2        0.835777
# 3        0.760315
# 4        0.775163
# 5        0.814134
# 6        0.804959

# %% [markdown]
# so basing on the above results we'll use AdaBoostClassifier to boost the model. Taking SVC as the base model to boost

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=125)
svc=SVC(kernel='rbf')
para={'n_estimators':(70,80),'learning_rate':(0.1,0.0023,0.25)}
abc=AdaBoostClassifier(base_estimator=svc,algorithm='SAMME')
abc_rs=rsv(abc,para,cv=30)
abc_rs.fit(x_train,y_train)
print("best parameters:", abc_rs.best_params_)
print("\n best score:",abc_rs.best_score_)
# Out:
# best parameters: {'n_estimators': 70, 'learning_rate': 0.1}
#
#  best score: 0.8266953713670614

# %%
#creating the model using the abc parameters
abc=AdaBoostClassifier(base_estimator=svc,algorithm='SAMME',n_estimators=70,learning_rate=0.1)

m8=acusr(abc,x,y)
# Out:
# In this AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=SVC(C=1.0, cache_size=200, class_weight=None,
#                                       coef0=0.0, decision_function_shape='ovr',
#                                       degree=3, gamma='auto_deprecated',
#                                       kernel='rbf', max_iter=-1,
#                                       probability=False, random_state=None,
#                                       shrinking=True, tol=0.001,
#                                       verbose=False),
#                    learning_rate=0.1, n_estimators=70, random_state=None)
#
# The best suited random_score is:  106
#
# Accuracy score: 0.8724279835390947
#
# F1 SCORE: 0.0
#
# CONFUSION MATRIX:
#  [[401   0]
#  [ 85   0]]
#
# AUC_ROC Score:
#  0.5

# %% [markdown]
# as boosting is not goving ample results so selecting logistic Regression as our final model

# %%
#saving the model
joblib.dump(logi,'IBM_HR_LOGI.pkl')
# Out:
# ['IBM_HR_LOGI.pkl']
